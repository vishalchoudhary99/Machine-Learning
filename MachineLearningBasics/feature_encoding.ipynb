# %% [markdown]
# # Feature Encoding

# %%
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.preprocessing  import OrdinalEncoder

# %%
data = fetch_openml('car',as_frame = True).frame

print(type(data))
# Out:
# d:\scikit-learn.py\.venv\Lib\site-packages\sklearn\datasets\_openml.py:328: UserWarning: Multiple active versions of the dataset matching the name car exist. Versions may be fundamentally different, returning version 2. Available versions:
# - version 2, status: active
#   url: https://www.openml.org/search?type=data&id=991
# - version 3, status: active
#   url: https://www.openml.org/search?type=data&id=40975
#
#   warn(warning_msg)

# %%
data
# Out:
#      buying  maint  doors persons lug_boot safety binaryClass
# 0     vhigh  vhigh      2       2    small    low           P
# 1     vhigh  vhigh      2       2    small    med           P
# 2     vhigh  vhigh      2       2    small   high           P
# 3     vhigh  vhigh      2       2      med    low           P
# 4     vhigh  vhigh      2       2      med    med           P
# ...     ...    ...    ...     ...      ...    ...         ...
# 1723    low    low  5more    more      med    med           N
# 1724    low    low  5more    more      med   high           N
# 1725    low    low  5more    more      big    low           P
# 1726    low    low  5more    more      big    med           N
# 1727    low    low  5more    more      big   high           N
#
# [1728 rows x 7 columns]

# %%
data['lug_boot'].unique()
# Out:
# ['small', 'med', 'big']
# Categories (3, str): ['big', 'med', 'small']

# %%
columns_to_encode = ['lug_boot','safety']

# Method 1 : Label Encoding
encoder = OrdinalEncoder(categories = [['small','med','big'],['low','med','high']])
data[columns_to_encode] = encoder.fit_transform(data[columns_to_encode])
data

# Method 2 : Label Encoding
# lug_boot_dict = {'small' : 0 , 'med' : 1 ,'big' : 2}
# safety_dict = {'low' : 0  , 'med' : 1, 'high' : 2}

# data['lug_boot'] = data['lug_boot'].map(lug_boot_dict)
# data['safety'] = data['safety'].map(safety_dict)
# data
# Out:
#      buying  maint  doors persons  lug_boot  safety binaryClass
# 0     vhigh  vhigh      2       2       0.0     0.0           P
# 1     vhigh  vhigh      2       2       0.0     1.0           P
# 2     vhigh  vhigh      2       2       0.0     2.0           P
# 3     vhigh  vhigh      2       2       1.0     0.0           P
# 4     vhigh  vhigh      2       2       1.0     1.0           P
# ...     ...    ...    ...     ...       ...     ...         ...
# 1723    low    low  5more    more       1.0     1.0           N
# 1724    low    low  5more    more       1.0     2.0           N
# 1725    low    low  5more    more       2.0     0.0           P
# 1726    low    low  5more    more       2.0     1.0           N
# 1727    low    low  5more    more       2.0     2.0           N
#
# [1728 rows x 7 columns]

# %%
encoder.inverse_transform([[data['lug_boot'].iloc[0], data['safety'].iloc[0]]])
# Out:
# array([['small', 'low']], dtype=object)

# %%
data = fetch_openml('adult',as_frame = True).frame
data
# Out:
# d:\scikit-learn.py\.venv\Lib\site-packages\sklearn\datasets\_openml.py:328: UserWarning: Multiple active versions of the dataset matching the name adult exist. Versions may be fundamentally different, returning version 1. Available versions:
# - version 1, status: active
#   url: https://www.openml.org/search?type=data&id=179
# - version 2, status: active
#   url: https://www.openml.org/search?type=data&id=1590
#
#   warn(warning_msg)
#       age         workclass  fnlwgt  education  education-num  \
# 0       2         State-gov   77516  Bachelors             13
# 1       3  Self-emp-not-inc   83311  Bachelors             13
# 2       2           Private  215646    HS-grad              9
# 3       3           Private  234721       11th              7
# 4       1           Private  338409  Bachelors             13
# ...    ..               ...     ...        ...            ...
# 48837   2           Private  215419  Bachelors             13
# ...

# %%
data.occupation.value_counts()
# Out:
# occupation
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: count, dtype: int64

# %%
# from sklearn.preprocessing import OneHotEncoder
# encoder = OneHotEncoder(handle_unknown = 'ignore',sparse_output = False)
# encoded_values = encoder.fit_transform(data[['occupation','race']])
# new_cols = encoder.get_feature_names_out(['occupation','race'])
# encoded_values

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
# df_encoded = pd.DataFrame(encoded_values,columns = new_cols , index = data.index)
# final_df = pd.concat([data.drop(columns = ['occupation','race']) , df_encoded],axis = 1)
# final_df
encoder = LabelEncoder()

# %%
final_df = pd.get_dummies(data,columns = ['occupation','race'],prefix = ['occupation','race'])
dic = {True: 1, False: 0}
cols = ['occupation','race']
for col in final_df.columns:
    for word in cols:
        if word in col:
            final_df[col] = final_df[col].map(dic)

final_df
# Out:
#       age         workclass  fnlwgt  education  education-num  \
# 0       2         State-gov   77516  Bachelors             13
# 1       3  Self-emp-not-inc   83311  Bachelors             13
# 2       2           Private  215646    HS-grad              9
# 3       3           Private  234721       11th              7
# 4       1           Private  338409  Bachelors             13
# ...    ..               ...     ...        ...            ...
# 48837   2           Private  215419  Bachelors             13
# 48838   4               NaN  321403    HS-grad              9
# 48839   2           Private  374983  Bachelors             13
# 48840   2           Private   83891  Bachelors             13
# 48841   1      Self-emp-inc  182148  Bachelors             13
#
#            marital-status    relationship     sex capitalgain capitalloss  \
# 0           Never-married   Not-in-family    Male           1           0
# ...
