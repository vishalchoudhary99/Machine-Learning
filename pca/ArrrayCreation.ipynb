# %% [markdown]
# ## Array Creation

# %%
import numpy as np

# %%
arr = np.array([[[10,20],[20,30]],[[40,50],[60,70]],[[80,90],[50,40]]])
arr
# Out:
# array([[[10, 20],
#         [20, 30]],
#
#        [[40, 50],
#         [60, 70]],
#
#        [[80, 90],
#         [50, 40]]])

# %%
arr.ndim
# Out:
# 3

# %%
arr.shape
# Out:
# (3, 2, 2)

# %%
arr
# Out:
# array([[[10, 20],
#         [20, 30]],
#
#        [[40, 50],
#         [60, 70]],
#
#        [[80, 90],
#         [50, 40]]])
