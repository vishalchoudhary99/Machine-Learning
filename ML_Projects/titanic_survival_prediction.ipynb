# %% [markdown]
# <div style="background-color:#ffecd2; color:#0f0c29; text-align:center; padding:15px; font-size:15px; border-radius:25px;">TITANIC SURVIVAL PREDICTION MODEL</div>

# %%
# importing required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ## Loading and specting dataset

# %%
df = pd.read_csv(r'C:\Users\Dell\Downloads\archive (16)\Titanic-Dataset.csv', encoding = 'latin-1')
df

# %%
# Rearranging the columns and removing unnecessary index column
df = df[['Name','Sex','Age','SibSp', 'Parch','Ticket','Fare','Cabin','Pclass','Embarked','Survived']]
df

# %%
# Checking datatypes
df.info()

# %%
# Checking for mathematical overview in the columns
df.describe()

# %%
# Checking empty values 
df.isnull().sum()

# %%
# Checking for duplicate rows
df.duplicated().sum()

# %%
df['Name'].duplicated().sum()

# %%
# Getting unique values in columns with less than 20 unique values
for col in df.columns:
    if df[col].nunique() < 20:
        print(f'Col: {col}')
        print(df[col].value_counts())
        print('-' * 50)

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Handling Missing Values

# %%
df.drop(columns = ['Cabin'], inplace = True) # Removing feature Cabin because it have 77% empty values

df['Sex'] = df['Sex'].fillna(df['Sex'].mode()[0]) # Filling missing ages with mode

# %% [markdown]
# ### Inconsistent Formatting

# %%
# There is no need of incosistent formatting because there is not inconsistent formatting

# %% [markdown]
# ### Handling Duplicates

# %%
for col in df.columns:
    print(f'{col}: ',df[col].duplicated().sum())
